# %%
import numpy as np
import pandas as pd
import sys
import utils

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# First, we load in our data set with the `utils` helpers that are provided along with the dataset that can be found [here](https://github.com/mdeff/fma).

# %%
tracks = utils.load('./fma_metadata/tracks.csv', nrows=10)

# %%
features = utils.load('./fma_metadata/features.csv', nrows=10)

# %% [markdown]
# Then, we filter down the tracks DataFrame to only the `track_id` and `genres`.

# %%
# dataframe with only track_id and genre ids
trackid_genres = tracks['track'].filter(['track_id', 'genres'])

# %% [markdown]
# Finally, we merge the `features` DataFrame containing musical features generated with [librosa](https://librosa.github.io/librosa/), and our target labels _(the genres)_, stored in the `trackid_genres` DataFrame.

# %%
features_genres = pd.merge(
    trackid_genres.head(10),
    features.head(10),
    on='track_id'
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 3 on the right)
#   warnings.warn(msg, UserWarning)

# %%
features_genres.head(10)
# Out:
#              genres  (chroma_cens, kurtosis, 01)  (chroma_cens, kurtosis, 02)  \
# track_id
# 2              [21]                     7.180653                     5.230309
# 3              [21]                     1.888963                     0.760539
# 5              [21]                     0.527563                    -0.077654
# 10             [10]                     3.702245                    -0.291193
# 20        [76, 103]                    -0.193837                    -0.198527
# 26        [76, 103]                    -0.699535                    -0.684158
# 30        [76, 103]                    -0.721487                    -0.848560
# 46        [76, 103]                    -0.119708                    -0.858814
# 48        [76, 103]                    -1.054053                     0.932339
# 134            [21]                     0.918445                     0.674147
#
#           (chroma_cens, kurtosis, 03)  (chroma_cens, kurtosis, 04)  \
# track_id
# 2                            0.249321                     1.347620
# 3                            0.345297                     2.295201
# 5                           -0.279610                     0.685883
# 10                           2.196742                    -0.234449
# 20                           0.201546                     0.258556
# 26                           0.048825                     0.042659
# 30                           0.890904                     0.088620
# 46                           2.362546                     0.106584
# 48                           0.528064                    -1.035338
# 134                          0.577818                     1.281117
#
#           (chroma_cens, kurtosis, 05)  (chroma_cens, kurtosis, 06)  \
# track_id
# 2                            1.482478                     0.531371
# 3                            1.654031                     0.067592
# 5                            1.937570                     0.880839
# 10                           1.367364                     0.998411
# 20                           0.775204                     0.084794
# 26                          -0.818967                    -0.917123
# 30                          -0.445513                    -1.271170
# 46                          -1.315912                    -1.220354
# 48                          -1.000682                    -1.119304
# 134                          0.933746                     0.078177
#
#           (chroma_cens, kurtosis, 07)  (chroma_cens, kurtosis, 08)  \
# track_id
# 2                            1.481593                     2.691455
# 3                            1.366848                     1.054094
# 5                           -0.923192                    -0.927232
# 10                           1.770694                     1.604566
# 20                          -0.289294                    -0.816410
# 26                          -0.901834                    -0.066845
# 30                          -1.240190                    -1.343765
# 46                          -1.668162                    -0.516033
# 48                           1.166990                    -1.002603
# 134                          1.199204                    -0.175223
#
#           (chroma_cens, kurtosis, 09)       ...        (tonnetz, std, 04)  \
# track_id                                    ...
# 2                            0.866868       ...                  0.054125
# 3                            0.108103       ...                  0.063831
# 5                            0.666617       ...                  0.040730
# 10                           0.521217       ...                  0.074358
# 20                           0.043851       ...                  0.095003
# 26                          -0.291037       ...                  0.103717
# 30                          -0.905600       ...                  0.141693
# 46                          -0.536395       ...                  0.132632
# 48                          -1.094999       ...                  0.141955
# 134                          0.925482       ...                  0.058766
#
#           (tonnetz, std, 05)  (tonnetz, std, 06)  (zcr, kurtosis, 01)  \
# track_id
# 2                   0.012226            0.012111             5.758890
# 3                   0.014212            0.017740             2.824694
# 5                   0.012691            0.014759             6.808415
# 10                  0.017952            0.013921            21.434212
# 20                  0.022492            0.021355            16.669037
# 26                  0.025541            0.023846            41.645809
# 30                  0.020426            0.025418             8.166595
# 46                  0.033212            0.021310            14.731083
# 48                  0.024654            0.025203            24.550789
# 134                 0.016322            0.015819             4.731087
#
#           (zcr, max, 01)  (zcr, mean, 01)  (zcr, median, 01)  (zcr, min, 01)  \
# track_id
# 2               0.459473         0.085629           0.071289        0.000000
# 3               0.466309         0.084578           0.063965        0.000000
# 5               0.375000         0.053114           0.041504        0.000000
# 10              0.452148         0.077515           0.071777        0.000000
# 20              0.469727         0.047225           0.040039        0.000977
# 26              0.250488         0.018388           0.015625        0.000000
# 30              0.546875         0.054417           0.036133        0.002441
# 46              0.223633         0.036601           0.032227        0.000000
# 48              0.371582         0.033015           0.022461        0.000000
# 134             0.419434         0.064370           0.050781        0.000000
#
#           (zcr, skew, 01)  (zcr, std, 01)
# track_id
# 2                2.089872        0.061448
# 3                1.716724        0.069330
# 5                2.193303        0.044861
# 10               3.542325        0.040800
# 20               3.189831        0.030993
# 26               4.690596        0.014598
# 30               2.244708        0.052674
# 46               2.848736        0.020713
# 48               4.406733        0.039016
# 134              1.806106        0.054623
#
# [10 rows x 519 columns]

# %% [markdown]
# Then, before we can start training, we need to convert the genre IDs into a 161x1 vector containing 0s and 1s, with 1s representing the correct genres.
